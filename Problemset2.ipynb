# %% [raw]
# Question 1

# %%
a = 0

def b():
    global a
    a = c(a)

def c(a):
    return a + 2

b()
b()
b()

a  # This will display the value of 'a' after the function calls
# Out:
# 6

# %% [markdown]
# ##### Explanation
# - First variable name a is defined
#
# - function named `b` is defined.
#
#   - Inside this function, we make variable a as globel
#   - Within `b`, a function named `c` is called with the current value of `a` as an argument.
#   - the result of c is assinged back to variable a
#
# - Function c simply takes any argument and adds 2 to it
#
# - we call function three times :  `b()`, `b()`, and `b()`.
#   - This results in the following sequence of operations:
#     - The first call to `b` updates `a` to 2.
#     - The second call to `b` updates `a` to 4.
#     - The third call to `b` updates `a` to 6.
#
# - The value 6 is displayed as result of printing variable a. Because 3 time calls to function b makes it value 6.

# %% [raw]
# Question 2

# %%
def fileLength(file_path):
    try:
        with open(file_path, 'r') as file:
            file_content = file.read()
            length = len(file_content)
        return length
    except FileNotFoundError:
        return f"File {file_path} not found."

# %%
print(fileLength('Filelength.txt')) 
print(fileLength('idterm.py'))
# Out:
# 123
# File idterm.py not found.

# %% [raw]
# Question 3

# %%
class Marsupial:
    def __init__(self):
        self.pouch = []

    def put_in_pouch(self, item):
        self.pouch.append(item)

    def pouch_contents(self):
        return self.pouch

class Kangaroo(Marsupial):
    def __init__(self, x=0, y=0):
        super().__init__()
        self.x = x
        self.y = y

    def jump(self, dx, dy):
        self.x += dx
        self.y += dy

    def __str__(self):
        return f"I am a Kangaroo located at coordinates ({self.x},{self.y})"


# Marsupial instance
m = Marsupial()
m.put_in_pouch('doll')
m.put_in_pouch('firetruck')
m.put_in_pouch('kitten')
print(m.pouch_contents())


# Kangaroo instance
k = Kangaroo()
print(k)
k.put_in_pouch('doll')
k.put_in_pouch('firetruck')
k.put_in_pouch('kitten')
print(k.pouch_contents())
k.jump(1, 0)
k.jump(1, 0)
k.jump(1, 0)
print(k)
# Out:
# ['doll', 'firetruck', 'kitten']
# I am a Kangaroo located at coordinates (0,0)
# ['doll', 'firetruck', 'kitten']
# I am a Kangaroo located at coordinates (3,0)

# %% [raw]
# Question 4

# %%
def collatz(x):
    if x == 1:
        return x
    else:
        print(x)
        if (x % 2 == 0):
            return collatz(x//2)
        else:
            return collatz(3*x+1)

# %%
collatz(1)
# Out:
# 1

# %%
collatz(15)
# Out:
# 15
# 46
# 23
# 70
# 35
# 106
# 53
# 160
# 80
# 40
# 20
# 10
# 5
# 16
# 8
# 4
# 2
# 1

# %% [markdown]
# Question 5

# %%
def binary(n):
    if n > 1:
        binary(n // 2)  # Recursive call for the integer division by 2
    print(n % 2, end='')
# Out:
# 01111001

# %%
binary(0)
# Out:
# 0

# %%
binary(1)
# Out:
# 1

# %%
binary(3)
# Out:
# 11

# %%
binary(9)
# Out:
# 1001

# %% [raw]
# Question 6

# %%
from html.parser import HTMLParser

class HeadingParser(HTMLParser):
    def __init__(self):
        super().__init__()
        self.indentation = 0
        self.in_heading = False

    def handle_starttag(self, tag, attrs):
        if tag.startswith('h') and tag[1:].isdigit():
            self.in_heading = True
            self.indentation = int(tag[1:]) - 1

    def handle_endtag(self, tag):
        if tag.startswith('h') and tag[1:].isdigit():
            self.in_heading = False

    def handle_data(self, data):
        if self.in_heading:
            print(" " * self.indentation + data.strip())

html_content = """
<!DOCTYPE html>
<html lang="en">
<head>
  <meta name="description" content="Webpage description goes here" />
  <meta charset="utf-8">
  <title>Change_me</title>
  <meta name="viewport" content="width=device-width, initial-scale=1">
  <meta name="author" content="">
  <link rel="stylesheet" href="css/style.css">
</head>
<body>
	<h1>W3C Mission</h1>
	<h2>Principles</h2>
</body>
</html>
"""

heading_parser = HeadingParser()
heading_parser.feed(html_content)
# Out:
# W3C Missions
#  Principles

# %% [raw]
# Question 7

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

def get_links(url):
    try:
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')
        links = [a.get('href') for a in soup.find_all('a', href=True)]
        return links
    except Exception as e:
        print(f"Error fetching links from {url}: {e}")
        return []

def webdir(url, depth, indent):
    if depth < 0:
        return

    links = get_links(url)

    print(" " * indent + url)

    for link in links:
        absolute_url = urljoin(url, link)
        webdir(absolute_url, depth - 1, indent + 2)

# Example usage
webdir("https://youtube.com", depth=2, indent=0)
# Out:
# https://youtube.com
#   https://youtube.com/
#     https://youtube.com/
#     https://youtube.com/
#     https://www.youtube.com/about/
#     https://www.youtube.com/about/press/
#     https://www.youtube.com/about/copyright/
#     https://youtube.com/t/contact_us/
#     https://www.youtube.com/creators/
#     https://www.youtube.com/ads/
#     https://developers.google.com/youtube
#     https://youtube.com/t/terms
#     https://youtube.com/t/privacy
#     https://www.youtube.com/about/policies/
#     https://www.youtube.com/howyoutubeworks?utm_campaign=ytgen&utm_source=ythp&utm_medium=LeftNav&utm_content=txt&u=https%3A%2F%2Fwww.youtube.com%2Fhowyoutubeworks%3Futm_source%3Dythp%26utm_medium%3DLeftNav%26utm_campaign%3Dytgen
#     https://youtube.com/new
#   https://youtube.com/
#     https://youtube.com/
#     https://youtube.com/
#     https://www.youtube.com/about/
#     https://www.youtube.com/about/press/
#     https://www.youtube.com/about/copyright/
#     https://youtube.com/t/contact_us/
#     https://www.youtube.com/creators/
#     https://www.youtube.com/ads/
#     https://developers.google.com/youtube
#     https://youtube.com/t/terms
#     https://youtube.com/t/privacy
#     https://www.youtube.com/about/policies/
#     https://www.youtube.com/howyoutubeworks?utm_campaign=ytgen&utm_source=ythp&utm_medium=LeftNav&utm_content=txt&u=https%3A%2F%2Fwww.youtube.com%2Fhowyoutubeworks%3Futm_source%3Dythp%26utm_medium%3DLeftNav%26utm_campaign%3Dytgen
#     https://youtube.com/new
#   https://www.youtube.com/about/
#     https://www.youtube.com/
#     https://www.youtube.com/about/#content
#     https://www.youtube.com/howyoutubeworks/
#     https://www.youtube.com/creators/
#     https://www.youtube.com/trends/
#     https://blog.youtube/
#     https://twitter.com/YouTube
#     https://www.instagram.com/youtube/
#     https://www.facebook.com/youtube/?ref=br_r
#     https://www.youtube.com/about/
#     https://blog.youtube/
#     https://www.youtube.com/howyoutubeworks/
#     https://www.youtube.com/jobs/
#     https://blog.youtube/press/
#     https://www.youtube.com/trends/
#     https://tv.youtube.com/learn/nflsundayticket
#     https://www.youtube.com/kids/
#     https://www.youtube.com/musicpremium
#     https://www.youtube.com/channel/UCqVDpXKLmKeBU_yyt_QkItQ
#     https://www.youtube.com/creators/podcasts/
#     https://www.youtube.com/premium/
#     https://www.youtube.com/ads/youtube-select/
#     https://studio.youtube.com/
#     https://tv.youtube.com/
#     https://developers.google.com/youtube
#     https://www.youtube.com/ads/
#     https://www.youtube.com/yt/family/
#     https://www.youtube.com/creatorresearch/
#     https://servicesdirectory.withyoutube.com/
#     https://artists.youtube.com/
#     https://www.youtube.com/creators/
#     https://www.youtube.com/nextup/
#     https://vr.youtube.com/
#     https://www.youtube.com/creators-for-change/
#     https://www.youtube.com/csai-match/
#     https://socialimpact.youtube.com/
#     https://www.youtube.com/about/
#     https://blog.youtube/
#     https://www.youtube.com/howyoutubeworks/
#     https://www.youtube.com/jobs/
#     https://blog.youtube/press/
#     https://www.youtube.com/trends/
#     https://tv.youtube.com/learn/nflsundayticket
#     https://www.youtube.com/kids/
#     https://www.youtube.com/musicpremium
#     https://www.youtube.com/channel/UCqVDpXKLmKeBU_yyt_QkItQ
#     https://www.youtube.com/creators/podcasts/
#     https://www.youtube.com/premium/
#     https://www.youtube.com/ads/youtube-select/
#     https://studio.youtube.com/
#     https://tv.youtube.com/
#     https://developers.google.com/youtube
#     https://www.youtube.com/ads/
#     https://www.youtube.com/yt/family/
#     https://www.youtube.com/creatorresearch/
#     https://servicesdirectory.withyoutube.com/
#     https://artists.youtube.com/
#     https://www.youtube.com/creators/
#     https://www.youtube.com/nextup/
#     https://vr.youtube.com/
#     https://www.youtube.com/creators-for-change/
#     https://www.youtube.com/csai-match/
#     https://socialimpact.youtube.com/
#     https://www.youtube.
#     https://www.youtube.com/csai-match/
#     https://socialimpact.youtube.com/
#     https://www.youtube.com
#     https://www.youtube.com/about/policies/
#     https://www.youtube.com/about/copyright/
#     https://www.youtube.com/about/brand-resources/
#     https://www.google.com/policies/privacy/
#     https://www.youtube.com/t/terms
#     https://support.google.com/youtube/#topic=9257498
#     http://www.google.com/ads/coupons/terms.html
#   https://developers.google.com/youtube
#     https://developers.google.com/youtube
#     https://developers.google.com/youtube
#     https://developers.google.com/youtube
#     https://developers.google.com/youtube/documentation
#     https://developers.google.com/youtube/code_samples
#     https://developers.google.com/youtube/terms/api-services-terms-of-service
#     https://developers.google.com/youtube
#     https://developers.google.com/youtube
#     https://developers.google.com/youtube
#     https://developers.google.com/youtube/documentation
#     https://developers.google.com/youtube/code_samples
#     https://developers.google.com/youtube/terms/api-services-terms-of-service
#     https://developers.google.com/
#     https://developers.google.com/products
#     https://developers.google.com/youtube
#     https://developers.google.com/youtube/iframe_api_reference
#     https://developers.google.com/youtube/iframe_api_reference
#     https://developers.google.com/youtube/iframe_api_reference
#     https://developers.google.com/youtube/android/player
#     https://developers.google.com/youtube/v3/guides/ios_youtube_helper
#     https://developers.google.com/youtube/player_parameters
#     https://developers.google.com/youtube/v3/getting-started
#     https://developers.google.com/youtube/v3/getting-started
#     https://developers.google.com/youtube/v3/getting-started
#     https://developers.google.com/youtube/v3/docs
#     https://developers.google.com/youtube/v3/code_samples
#     https://developers.google.com/youtube/reporting
#     https://developers.google.com/youtube/reporting
#     https://developers.google.com/youtube/reporting
#     https://developers.google.com/youtube/reporting/v1/code_samples
#     https://developers.google.com/youtube/youtube_subscribe_button
#     https://developers.google.com/youtube/youtube_subscribe_button
#     https://developers.google.com/youtube/youtube_subscribe_button
#     https://developers.google.com/youtube/v3/live/getting-started
#     https://developers.google.com/youtube/v3/live/getting-started
#     https://developers.google.com/youtube/v3/live/getting-started
#     https://blog.youtube
#     https://github.com/youtube/api-samples
#     https://issuetracker.google.com/issues/new?component=186600&template=874803
#     http://stackoverflow.com/questions/ask?tags=youtube-api
#     https://research.youtube/
#     https://developers.google.com/apis-explorer/#p/
#     https://developers.google.com/youtube/youtube_player_demo
#     https://developers.google.com/youtube/youtube_subscribe_button
#     https://issuetracker.google.com/issues/new?component=186600&template=874803
#     https://issuetracker.google.com/issues/new?component=186600&template=874803
#     https://issuetracker.google.com/issues?q=componentid:186600
#     https://developers.google.com/youtube/terms/api-services-terms-of-service
#     https://developers.google.com/youtube/terms/developer-policies
#     https://developers.google.com/youtube/terms/required-minimum-functionality
#     https://developers.google.com/youtube/terms/branding-guidelines
#     https://developers.google.com/
#     https://developer.android.com
#     https://developer.chrome.com/home
#     https://firebase.google.com
#     https://cloud.google.com
#     https://developers.google.com/products
#     https://developers.google.com/terms/site-terms
#     https://policies.google.com/privacy
#     https://developers.google.com/youtube
#     https://developers.google.com/newsletter/subscribe
#   https://youtube.com/t/terms
#     https://youtube.com/
#     https://youtube.com/t/terms_paidservice
#     https://youtube.com/t/usage_paycontent
#     https://youtube.com/t/policy_cns
#     https://youtube.com/t/copyright_notice
#     https://youtube.com/t/community_guidelines
#     https://youtube.com/t/terms#20c5cf0fa6
#     https://youtube.com/t/terms#eb887a967c
hl=en_GB
#     https://youtube.com/t/privacy?hl=en-GB#footnote-affiliates
#     https://youtube.com/t/privacy?hl=en-GB#footnote-legal
#     https://transparencyreport.google.com/user-data/overview?hl=en_GB
#     https://youtube.com/t/privacy?hl=en-GB#footnote-our-users
#     https://youtube.com/t/privacy?hl=en-GB#footnote-info
#     https://youtube.com/t/privacy?hl=en-GB#footnote-trends
#     https://youtube.com/t/privacy?hl=en-GB#footnote-specific-partners
#     https://safebrowsing.google.com/?utm_source=pp&hl=en_GB
#     https://www.google.com/landing/2step/?utm_source=pp&hl=en_GB
#     https://takeout.google.com/?utm_source=pp&hl=en_GB
#     https://youtube.com/t/privacy?hl=en-GB#footnote-delete-specific
#     https://myactivity.google.com/?utm_source=pp&hl=en_GB
#     https://myaccount.google.com/deleteservices?utm_source=pp&hl=en_GB
#     https://myaccount.google.com/deleteaccount?utm_source=pp&hl=en_GB
#     https://myaccount.google.com/delete-services-or-account?utm_source=pp&hl=en_GB
#     https://myaccount.google.com/personal-info?hl=en_GB
#     https://support.google.com/photos/answer/6128858?hl=en_GB
#     https://support.google.com/docs/answer/6023494?hl=en_GB
#     https://myactivity.google.com/myactivity?hl=en_GB
#     https://support.google.com/accounts/answer/465?authuser=0&hl=en_GB#auto-delete
#     https://youtube.com/t/technologies/ads?hl=en-GB
#     https://youtube.com/t/technologies/retention?hl=en-GB
#     https://youtube.com/t/privacy?hl=en-GB#footnote-servers
#     https://youtube.com/t/privacy/frameworks?hl=en-GB
#     https://youtube.com/t/privacy?hl=en-GB#footnote-affiliates
#     https://youtube.com/t/privacy/archive?hl=en-GB
#     https://payments.google.com/legaldocument?family=0.privacynotice&hl=en-GB
#     https://fiber.google.com/legal/privacy.html
#     https://fi.google.com/about/tos/#project-fi-privacy-notice
#     https://workspace.google.com/terms/education_privacy.html
#     https://ssl.gstatic.com/seekh/intl/en/privacy
#     https://kids.youtube.com/privacynotice
#     https://families.google.com/familylink/privacy/child-policy/
#     https://families.google.com/familylink/privacy/child-disclosure/?hl=en_GB
#     https://assistant.google.com/privacy-notice-childrens-features/?hl=en_GB
#     https://cloud.google.com/terms/cloud-privacy-notice?hl=en_GB
#     https://myaccount.google.com/?hl=en_GB
#     https://myaccount.google.com/privacycheckup?utm_source=pp&utm_medium=Promo-in-product&utm_campaign=pp_body&hl=en_GB
#     https://www.google.com/intl/en-GB/safetycenter/
#     https://www.google.com/policies/privacy/teens/?hl=en_GB
#     https://youtube.com/t/privacy?hl=en-GB
#     https://youtube.com/t/technologies?hl=en-GB
#     https://youtube.com/t/technologies/cookies?hl=en-GB
#     https://youtube.com/t/technologies/ads?hl=en-GB
#     https://youtube.com/t/technologies/partner-sites?hl=en-GB
#     https://privacy.google.com/businesses/affiliates?hl=en_GB
#     https://youtube.com/t/technologies/cookies?hl=en-GB
#     https://youtube.com/t/technologies/partner-sites?hl=en-GB
#     https://myaccount.google.com/?hl=en_GB
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-e3974f0c9f96> in <module>
#      26
#      27 # Example usage
# ---> 28 webdir("https://youtube.com", depth=2, indent=0)
#
# <ipython-input-2-e3974f0c9f96> in webdir(url, depth, indent)
#      23     for link in links:
#      24         absolute_url = urljoin(url, link)
# ---> 25         webdir(absolute_url, depth - 1, indent + 2)
#      26
#      27 # Example usage
#
# <ipython-input-2-e3974f0c9f96> in webdir(url, depth, indent)
#      23     for link in links:
#      24         absolute_url = urljoin(url, link)
# ---> 25         webdir(absolute_url, depth - 1, indent + 2)
#      26
#      27 # Example usage
#
# <ipython-input-2-e3974f0c9f96> in webdir(url, depth, indent)
#      17         return
#      18
# ---> 19     links = get_links(url)
#      20
#      21     print(" " * indent + url)
#
# <ipython-input-2-e3974f0c9f96> in get_links(url)
#       5 def get_links(url):
#       6     try:
# ----> 7         response = requests.get(url)
#       8         soup = BeautifulSoup(response.text, 'html.parser')
#       9         links = [a.get('href') for a in soup.find_all('a', href=True)]
#
# c:\users\asus\appdata\local\programs\python\python39\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# c:\users\asus\appdata\local\programs\python\python39\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# c:\users\asus\appdata\local\programs\python\python39\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# c:\users\asus\appdata\local\programs\python\python39\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     723             # Redirect resolving generator.
#     724             gen = self.resolve_redirects(r, request, **kwargs)
# --> 725             history = [resp for resp in gen]
#     726         else:
#     727             history = []
#
# c:\users\asus\appdata\local\programs\python\python39\lib\site-packages\requests\sessions.py in <listcomp>(.0)
#     723             # Redirect resolving generator.
#     724             gen = self.resolve_redirects(r, request, **kwargs)
# --> 725             history = [resp for resp in gen]
#     726         else:
#     727             history = []
#
# c:\users\asus\appdata\local\programs\python\python39\lib\site-packages\requests\sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     264             else:
#     265
# --> 266                 resp = self.send(
#     267                     req,
#     268                     stream=stream,
#
# c:\users\asus\appdata\local\programs\python\python39\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     745
#     746         if not stream:
# --> 747             r.content
#     748
#     749         return r
#
# c:\users\asus\appdata\local\programs\python\python39\lib\site-packages\requests\models.py in content(self)
#     897                 self._content = None
#     898             else:
# --> 899                 self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     900
#     901         self._content_consumed = True
#
# c:\users\asus\appdata\local\programs\python\python39\lib\site-packages\requests\models.py in generate()
#     814             if hasattr(self.raw, "stream"):
#     815                 try:
# --> 816                     yield from self.raw.stream(chunk_size, decode_content=True)
#     817                 except ProtocolError as e:
#     818                     raise ChunkedEncodingError(e)
#
# c:\users\asus\appdata\local\programs\python\python39\lib\site-packages\urllib3\response.py in stream(self, amt, decode_content)
#    1038         """
#    1039         if self.chunked and self.supports_chunked_reads():
# -> 1040             yield from self.read_chunked(amt, decode_content=decode_content)
#    1041         else:
#    1042             while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
#
# c:\users\asus\appdata\local\programs\python\python39\lib\site-packages\urllib3\response.py in read_chunked(self, amt, decode_content)
#    1185                 if self.chunk_left == 0:
#    1186                     break
# -> 1187                 chunk = self._handle_chunk(amt)
#    1188                 decoded = self._decode(
#    1189                     chunk, decode_content=decode_content, flush_decoder=False
#
# c:\users\asus\appdata\local\programs\python\python39\lib\site-packages\urllib3\response.py in _handle_chunk(self, amt)
#    1136             returned_chunk = value
#    1137         else:  # amt > self.chunk_left
# -> 1138             returned_chunk = self._fp._safe_read(self.chunk_left)  # type: ignore[union-attr]
#    1139             self._fp._safe_read(2)  # type: ignore[union-attr] # Toss the CRLF at the end of the chunk.
#    1140             self.chunk_left = None
#
# c:\users\asus\appdata\local\programs\python\python39\lib\http\client.py in _safe_read(self, amt)
#     610         IncompleteRead exception can be used to detect the problem.
#     611         """
# --> 612         data = self.fp.read(amt)
#     613         if len(data) < amt:
#     614             raise IncompleteRead(data, amt-len(data))
#
# c:\users\asus\appdata\local\programs\python\python39\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# c:\users\asus\appdata\local\programs\python\python39\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# c:\users\asus\appdata\local\programs\python\python39\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [raw]
# Question 8

# %%
import sqlite3

# Establishing a connection to the SQLite database (or creating one if it doesn't exist)
conn = sqlite3.connect('Nawaraj_Climate_Database.db')

# Initializing a cursor object for interacting with the database
cursor = conn.cursor()

# Checking and, if necessary, dropping the Weather_Info table (to ensure a fresh start)
cursor.execute("DROP TABLE IF EXISTS Weather_Info")

# Defining the SQL statement to create the Weather_Info table
table = """
CREATE TABLE Weather_Info (
    City TEXT,
    Country TEXT,
    Season TEXT,
    Temperature REAL,
    Rainfall REAL
);
"""

# Executing the CREATE TABLE statement
cursor.execute(table)

# Defining the SQL statement for inserting data into the Weather_Info table
weather_data = """
INSERT INTO Weather_Info (City, Country, Season, Temperature, Rainfall)
VALUES
  ('Mumbai', 'India', 'Winter', 24.8, 5.9),
  ('Mumbai', 'India', 'Spring', 28.4, 16.2),
  ('Mumbai', 'India', 'Summer', 27.9, 1549.4),
  ('Mumbai', 'India', 'Fall', 27.6, 346.0),
  ('London', 'United Kingdom', 'Winter', 4.2, 207.7),
  ('London', 'United Kingdom', 'Spring', 8.3, 169.6),
  ('London', 'United Kingdom', 'Summer', 15.7, 157.0),
  ('London', 'United Kingdom', 'Fall', 10.4, 218.5),
  ('Cairo', 'Egypt', 'Winter', 13.6, 16.5),
  ('Cairo', 'Egypt', 'Spring', 20.7, 6.5),
  ('Cairo', 'Egypt', 'Summer', 27.7, 0.1),
  ('Cairo', 'Egypt', 'Fall', 22.2, 4.5);
"""

# Executing the INSERT statement
cursor.executescript(weather_data)

# Committing the changes to the database
conn.commit()

# Closing the connection
conn.close()

# %%
conn = sqlite3.connect('Nawaraj_Climate_Database.db')

cursor = conn.cursor()

cursor.execute(""" Select * from Weather_Info """)

rows = cursor.fetchall()

for row in rows:
    print(row)

conn.close()
# Out:
# ('Mumbai', 'India', 'Winter', 24.8, 5.9)
# ('Mumbai', 'India', 'Spring', 28.4, 16.2)
# ('Mumbai', 'India', 'Summer', 27.9, 1549.4)
# ('Mumbai', 'India', 'Fall', 27.6, 346.0)
# ('London', 'United Kingdom', 'Winter', 4.2, 207.7)
# ('London', 'United Kingdom', 'Spring', 8.3, 169.6)
# ('London', 'United Kingdom', 'Summer', 15.7, 157.0)
# ('London', 'United Kingdom', 'Fall', 10.4, 218.5)
# ('Cairo', 'Egypt', 'Winter', 13.6, 16.5)
# ('Cairo', 'Egypt', 'Spring', 20.7, 6.5)
# ('Cairo', 'Egypt', 'Summer', 27.7, 0.1)
# ('Cairo', 'Egypt', 'Fall', 22.2, 4.5)

# %%
import sqlite3

# Create a connection to the SQLite database
conn = sqlite3.connect('Nawaraj_Climate_Database.db')

# Create cursor objects to interact with the database
cursor_a = conn.cursor()
cursor_b = conn.cursor()
cursor_c = conn.cursor()
cursor_d = conn.cursor()
cursor_e = conn.cursor()
cursor_f = conn.cursor()
cursor_g = conn.cursor()
cursor_h = conn.cursor()

cursor_a.execute("""SELECT Temperature 
                    FROM Weather_Info
                 """)

cursor_b.execute("""SELECT DISTINCT City 
                    FROM Weather_Info
                 """)

cursor_c.execute("""SELECT * 
                    FROM Weather_Info 
                    WHERE Country = 'India'
                 """)

cursor_d.execute("""SELECT *  
                    FROM Weather_Info 
                    WHERE Season = 'Fall'
                 """)

cursor_e.execute("""SELECT City 
                          ,Country 
                          ,Season 
                    FROM Weather_Info
                    GROUP BY City, Country, Season 
                    HAVING AVG(Rainfall) BETWEEN 200 AND 400
                 """)

cursor_f.execute("""SELECT City
                          ,Country
                    FROM Weather_Info
                    WHERE Season = 'Fall'
                    GROUP BY City, Country
                    HAVING AVG(Temperature) > 20
                    ORDER BY AVG(Temperature) ASC
                 """)

cursor_g.execute("""SELECT SUM(Rainfall) AS TotalRainfall
                    FROM Weather_Info
                    WHERE City = 'Cairo'
                 """)

cursor_h.execute("""SELECT Season, SUM(Rainfall) AS TotalRainfall
                    FROM Weather_Info
                    GROUP BY Season
                """)

rows_a = cursor_a.fetchall()
rows_b = cursor_b.fetchall()
rows_c = cursor_c.fetchall()
rows_d = cursor_d.fetchall()
rows_e = cursor_e.fetchall()
rows_f = cursor_f.fetchall()
rows_g = cursor_g.fetchall()
rows_h = cursor_h.fetchall()

conn.close()

# %%
print("a) All the temperature data.\n")
for row in rows_a:
    print(row)
# Out:
# a) All the temperature data.
#
# (24.8,)
# (28.4,)
# (27.9,)
# (27.6,)
# (4.2,)
# (8.3,)
# (15.7,)
# (10.4,)
# (13.6,)
# (20.7,)
# (27.7,)
# (22.2,)

# %%
print("b) All the cities, but without repetition.\n")
for row in rows_b:
    print(row)
# Out:
# b) All the cities, but without repetition.
#
# ('Mumbai',)
# ('London',)
# ('Cairo',)

# %%
print("c) All the records for India.\n")
for row in rows_c:
    print(row)
# Out:
# c) All the records for India.
#
# ('Mumbai', 'India', 'Winter', 24.8, 5.9)
# ('Mumbai', 'India', 'Spring', 28.4, 16.2)
# ('Mumbai', 'India', 'Summer', 27.9, 1549.4)
# ('Mumbai', 'India', 'Fall', 27.6, 346.0)

# %%
print("d) All the Fall records.\n")
for row in rows_d:
    print(row)
# Out:
# d) All the Fall records.
#
# ('Mumbai', 'India', 'Fall', 27.6, 346.0)
# ('London', 'United Kingdom', 'Fall', 10.4, 218.5)
# ('Cairo', 'Egypt', 'Fall', 22.2, 4.5)

# %%
print("e) The city, country, and season for which the average rainfall is between 200 and 400 millimeters.\n")
for row in rows_e:
    print(row)
# Out:
# e) The city, country, and season for which the average rainfall is between 200 and 400 millimeters.
#
# ('London', 'United Kingdom', 'Fall')
# ('London', 'United Kingdom', 'Winter')
# ('Mumbai', 'India', 'Fall')

# %%
print("f) The city and country for which the average Fall temperature is above 20 degrees, in increasing temperature order\n")
for row in rows_f:
    print(row)
# Out:
# f) The city and country for which the average Fall temperature is above 20 degrees, in increasing temperature order
#
# ('Cairo', 'Egypt')
# ('Mumbai', 'India')

# %%
print("g) The total annual rainfall for Cairo\n")
for row in rows_g:
    print(row)
# Out:
# g) The total annual rainfall for Cairo
#
# (27.6,)

# %%
print("h) The total rainfall for each season.\n")
for row in rows_h:
    print(row)
# Out:
# h) The total rainfall for each season.
#
# ('Fall', 569.0)
# ('Spring', 192.29999999999998)
# ('Summer', 1706.5)
# ('Winter', 230.1)

# %% [raw]
# Question 9

# %%
words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# %%
uppercase_words = [word.upper() for word in words]
print(f"a) {uppercase_words}")
# Out:
# a) ['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE', 'LAZY', 'DOG']

# %%
lowercase_words = [word.lower() for word in words]
print(f"b) {lowercase_words}")
# Out:
# b) ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# %%
word_lengths = [len(word) for word in words]
print(f"c) {word_lengths}")
# Out:
# c) [3, 5, 5, 3, 5, 4, 3, 4, 3]

# %%
word_info = [[word.upper(), word.lower(), len(word)] for word in words]
print(f"d) {word_info}")
# Out:
# d) [['THE', 'the', 3], ['QUICK', 'quick', 5], ['BROWN', 'brown', 5], ['FOX', 'fox', 3], ['JUMPS', 'jumps', 5], ['OVER', 'over', 4], ['THE', 'the', 3], ['LAZY', 'lazy', 4], ['DOG', 'dog', 3]]

# %%
long_words = [word for word in words if len(word) >= 4]
print(f"e) {long_words}")
# Out:
# e) ['quick', 'brown', 'jumps', 'over', 'lazy']
